# %%
x={"article": 17825828, "categories": ["Cities_and_towns_in_Cooch_Behar_district"], "sections": ["Etymology", "Geography", "Demographics", "Infrastructure", "Transport", "Education", "Culture"], "recs": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Civic Administration", "Major localities", "Occupations", "Cultural activities", "Etymology", "History", "Climate", "Economy", "Utility services", "Tourism"], "filtered_recs": [{"k": 2, "recs_filtered": ["Geography", "Demographics"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 3, "recs_filtered": ["Geography", "Demographics", "Education"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 4, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 5, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 6, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 7, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 8, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 9, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 10, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [], "semantic_filtering_level": 3}, {"k": 11, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}], "semantic_filtering_level": 3}, {"k": 12, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}], "semantic_filtering_level": 3}, {"k": 13, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}], "semantic_filtering_level": 3}, {"k": 14, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 3}, {"k": 15, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 3}, {"k": 16, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"History": 0.6666666666666667, "Culture": 4.166666666666667, "Cultural activities": 0.01185875105476435}], "semantic_filtering_level": 3}, {"k": 17, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "Climate"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"History": 0.6666666666666667, "Culture": 4.166666666666667, "Cultural activities": 0.01185875105476435}], "semantic_filtering_level": 3}, {"k": 18, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "Climate", "Economy"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"History": 0.6666666666666667, "Culture": 4.166666666666667, "Cultural activities": 0.01185875105476435}], "semantic_filtering_level": 3}, {"k": 19, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "Climate", "Economy", "Utility services"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"History": 0.6666666666666667, "Culture": 4.166666666666667, "Cultural activities": 0.01185875105476435}], "semantic_filtering_level": 3}, {"k": 20, "recs_filtered": ["Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "Climate", "Economy", "Utility services", "Tourism"], "semantic_similar_sections": [{"Geography": 1.1379310344827587, "Demographics": 0.06896551724137931, "Civic administration": 8.758620689655173, "Civic Administration": 0.4749854656379138}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"History": 0.6666666666666667, "Culture": 4.166666666666667, "Cultural activities": 0.01185875105476435}], "semantic_filtering_level": 3}, {"k": 2, "recs_filtered": ["Geography", "Demographics"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 3, "recs_filtered": ["Geography", "Demographics", "Education"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 4, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 5, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 6, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 7, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 8, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 9, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 10, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [], "semantic_filtering_level": 2}, {"k": 11, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}], "semantic_filtering_level": 2}, {"k": 12, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}], "semantic_filtering_level": 2}, {"k": 13, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}], "semantic_filtering_level": 2}, {"k": 14, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 15, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 16, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "History"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 17, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "History", "Climate"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 18, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "History", "Climate", "Economy"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 19, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "History", "Climate", "Economy", "Utility services"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 20, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Occupations", "Etymology", "History", "Climate", "Economy", "Utility services", "Tourism"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Major localities": 0.0021116138763197585, "Transport": 3.5}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 2}, {"k": 2, "recs_filtered": ["Geography", "Demographics"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 3, "recs_filtered": ["Geography", "Demographics", "Education"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 4, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 5, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 6, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 7, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 8, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 9, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 10, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [], "semantic_filtering_level": 1}, {"k": 11, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}], "semantic_filtering_level": 1}, {"k": 12, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}], "semantic_filtering_level": 1}, {"k": 13, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}], "semantic_filtering_level": 1}, {"k": 14, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 15, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 16, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology", "History"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 17, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology", "History", "Climate"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 18, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology", "History", "Climate", "Economy"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 19, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology", "History", "Climate", "Economy", "Utility services"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}, {"k": 20, "recs_filtered": ["Geography", "Demographics", "Education", "Healthcare", "Civic administration", "Transport", "Infrastructure", "Culture", "Sports", "Notable people", "Major localities", "Occupations", "Etymology", "History", "Climate", "Economy", "Utility services", "Tourism"], "semantic_similar_sections": [{"Civic administration": 8.758620689655173, "Civic Administration": 1.4189944134078214}, {"Culture": 4.166666666666667, "Cultural activities": 0.023408239700374533}], "semantic_filtering_level": 1}]}

# %%
last_filtered_recs=[]
last_rec=None
for i,y in enumerate(x['recs']):
    print(f'{i+1}: {y}')
for rec in x['filtered_recs']:
    if rec['recs_filtered']==last_filtered_recs:
        print("---")
        print(last_rec)
        print(rec)
    last_filtered_recs=rec['recs_filtered']
    last_rec=rec
# Out:
# 1: Geography
# 2: Demographics
# 3: Education
# 4: Healthcare
# 5: Civic administration
# 6: Transport
# 7: Infrastructure
# 8: Culture
# 9: Sports
# 10: Notable people
# 11: Civic Administration
# 12: Major localities
# 13: Occupations
# 14: Cultural activities
# 15: Etymology
# 16: History
# 17: Climate
# 18: Economy
# 19: Utility services
# 20: Tourism
# ---
# {'k': 11, 'recs_filtered': ['Education', 'Healthcare', 'Civic administration', 'Transport', 'Infrastructure', 'Culture', 'Sports', 'Notable people'], 'semantic_similar_sections': [{'Geography': 1.1379310344827587, 'Demographics': 0.06896551724137931, 'Civic administration': 8.758620689655173, 'Civic Administration': 0.4749854656379138}], 'semantic_filtering_level': 3}
# ...
