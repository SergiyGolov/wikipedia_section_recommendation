# %%
# %run ../utils/eval.py

# %%
load_filtering_results_and_plot("gini_threshold-0985_no_unknown_types")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.365
# 2: 0.524
# 3: 0.435
# 4: 0.367
# 5: 0.314
# 6: 0.271
# 7: 0.24
# 8: 0.216
# 9: 0.199
# 10: 0.187
# 11: 0.177
# 12: 0.169
# 13: 0.163
# 14: 0.16
# 15: 0.157
# 16: 0.154
# 17: 0.149
# 18: 0.144
# 19: 0.141
# 20: 0.134
#
# Mean recall
# 1: 0.201
# 2: 0.395
# 3: 0.465
# 4: 0.506
# 5: 0.527
# 6: 0.538
# 7: 0.548
# 8: 0.559
# 9: 0.572
# 10: 0.588
# 11: 0.607
# 12: 0.628
# 13: 0.65
# 14: 0.672
# 15: 0.693
# 16: 0.706
# 17: 0.708
# 18: 0.702
# 19: 0.699
# 20: 0.682
#
# F1 score
# 1: 0.259
# 2: 0.45
# 3: 0.45
# 4: 0.425
# 5: 0.393
# 6: 0.361
# 7: 0.333
# 8: 0.311
# 9: 0.295
# 10: 0.283
# 11: 0.274
# 12: 0.266
# 13: 0.261
# 14: 0.258
# 15: 0.256
# 16: 0.252
# 17: 0.246
# 18: 0.239
# 19: 0.235
# 20: 0.224
# gini_threshold-0985_no_unknown_types after semantic filtering, semantic filtering level 1
# Mean precision
# 1: 0.369
# 2: 0.508
# 3: 0.411
# 4: 0.341
# 5: 0.29
# 6: 0.254
# 7: 0.23
# 8: 0.214
# 9: 0.204
# 10: 0.199
# ...
