# %%
# %run ../utils/eval.py

# %%
load_epfl_results_and_plot()
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.575
# 2: 0.482
# 3: 0.413
# 4: 0.358
# 5: 0.318
# 6: 0.286
# 7: 0.26
# 8: 0.239
# 9: 0.221
# 10: 0.206
# 11: 0.193
# 12: 0.181
# 13: 0.172
# 14: 0.163
# 15: 0.155
# 16: 0.148
# 17: 0.142
# 18: 0.137
# 19: 0.131
# 20: 0.127
#
# Mean recall
# 1: 0.257
# 2: 0.4
# 3: 0.489
# 4: 0.548
# 5: 0.593
# 6: 0.628
# 7: 0.656
# 8: 0.68
# 9: 0.699
# 10: 0.716
# 11: 0.73
# 12: 0.743
# 13: 0.754
# 14: 0.763
# 15: 0.772
# 16: 0.78
# 17: 0.787
# 18: 0.793
# 19: 0.799
# 20: 0.804
#
# F1 score
# 1: 0.356
# 2: 0.438
# 3: 0.447
# 4: 0.433
# 5: 0.414
# 6: 0.393
# 7: 0.372
# 8: 0.353
# 9: 0.336
# 10: 0.32
# 11: 0.305
# 12: 0.292
# 13: 0.28
# 14: 0.269
# 15: 0.259
# 16: 0.249
# 17: 0.241
# 18: 0.233
# 19: 0.226
# 20: 0.219

# %%
load_results_and_plot("epfl_reproduction")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.531
# 2: 0.436
# 3: 0.368
# 4: 0.316
# 5: 0.277
# 6: 0.247
# 7: 0.223
# 8: 0.203
# 9: 0.187
# 10: 0.174
# 11: 0.162
# 12: 0.152
# 13: 0.144
# 14: 0.136
# 15: 0.129
# 16: 0.123
# 17: 0.118
# 18: 0.113
# 19: 0.109
# 20: 0.105
#
# Mean recall
# 1: 0.238
# 2: 0.363
# 3: 0.438
# 4: 0.486
# 5: 0.522
# 6: 0.549
# 7: 0.571
# 8: 0.588
# 9: 0.603
# 10: 0.615
# 11: 0.626
# 12: 0.636
# 13: 0.644
# 14: 0.652
# 15: 0.659
# 16: 0.665
# 17: 0.671
# 18: 0.676
# 19: 0.68
# 20: 0.685
#
# F1 score
# 1: 0.329
# 2: 0.396
# 3: 0.4
# 4: 0.383
# 5: 0.362
# 6: 0.34
# 7: 0.32
# 8: 0.302
# 9: 0.286
# 10: 0.271
# 11: 0.258
# 12: 0.246
# 13: 0.235
# 14: 0.225
# 15: 0.216
# 16: 0.208
# 17: 0.201
# 18: 0.194
# 19: 0.188
# 20: 0.182

# %%
load_results_and_plot("epfl_reproduction-category_section_counts_with_test_set")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.594
# 2: 0.501
# 3: 0.431
# 4: 0.374
# 5: 0.332
# 6: 0.298
# 7: 0.271
# 8: 0.249
# 9: 0.23
# 10: 0.214
# 11: 0.2
# 12: 0.188
# 13: 0.178
# 14: 0.169
# 15: 0.161
# 16: 0.153
# 17: 0.147
# 18: 0.141
# 19: 0.136
# 20: 0.131
#
# Mean recall
# 1: 0.27
# 2: 0.42
# 3: 0.514
# 4: 0.576
# 5: 0.623
# 6: 0.66
# 7: 0.689
# 8: 0.714
# 9: 0.734
# 10: 0.752
# 11: 0.767
# 12: 0.78
# 13: 0.792
# 14: 0.802
# 15: 0.811
# 16: 0.82
# 17: 0.827
# 18: 0.834
# 19: 0.841
# 20: 0.847
#
# F1 score
# 1: 0.371
# 2: 0.457
# 3: 0.469
# 4: 0.454
# 5: 0.433
# 6: 0.411
# 7: 0.389
# 8: 0.369
# 9: 0.35
# 10: 0.333
# 11: 0.318
# 12: 0.304
# 13: 0.291
# 14: 0.279
# 15: 0.268
# 16: 0.259
# 17: 0.25
# 18: 0.241
# 19: 0.234
# 20: 0.226

# %%
load_results_and_plot("epfl_reproduction_provided_category_section_counts")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.576
# 2: 0.484
# 3: 0.414
# 4: 0.359
# 5: 0.319
# 6: 0.286
# 7: 0.261
# 8: 0.239
# 9: 0.221
# 10: 0.206
# 11: 0.193
# 12: 0.182
# 13: 0.172
# 14: 0.163
# 15: 0.156
# 16: 0.149
# 17: 0.143
# 18: 0.137
# 19: 0.132
# 20: 0.127
#
# Mean recall
# 1: 0.258
# 2: 0.402
# 3: 0.49
# 4: 0.55
# 5: 0.596
# 6: 0.631
# 7: 0.659
# 8: 0.683
# 9: 0.702
# 10: 0.718
# 11: 0.733
# 12: 0.745
# 13: 0.756
# 14: 0.766
# 15: 0.774
# 16: 0.782
# 17: 0.789
# 18: 0.795
# 19: 0.801
# 20: 0.807
#
# F1 score
# 1: 0.357
# 2: 0.439
# 3: 0.449
# 4: 0.435
# 5: 0.415
# 6: 0.394
# 7: 0.373
# 8: 0.354
# 9: 0.337
# 10: 0.32
# 11: 0.306
# 12: 0.292
# 13: 0.28
# 14: 0.269
# 15: 0.259
# 16: 0.25
# 17: 0.241
# 18: 0.234
# 19: 0.226
# 20: 0.22

# %%
load_results_and_plot("gini_threshold-0985_no_unknown_types")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.648
# 2: 0.545
# 3: 0.466
# 4: 0.404
# 5: 0.355
# 6: 0.317
# 7: 0.286
# 8: 0.261
# 9: 0.241
# 10: 0.224
# 11: 0.209
# 12: 0.197
# 13: 0.186
# 14: 0.177
# 15: 0.168
# 16: 0.161
# 17: 0.154
# 18: 0.149
# 19: 0.143
# 20: 0.139
#
# Mean recall
# 1: 0.265
# 2: 0.412
# 3: 0.502
# 4: 0.562
# 5: 0.605
# 6: 0.635
# 7: 0.659
# 8: 0.677
# 9: 0.693
# 10: 0.706
# 11: 0.716
# 12: 0.726
# 13: 0.734
# 14: 0.741
# 15: 0.747
# 16: 0.753
# 17: 0.758
# 18: 0.763
# 19: 0.767
# 20: 0.771
#
# F1 score
# 1: 0.376
# 2: 0.469
# 3: 0.483
# 4: 0.47
# 5: 0.448
# 6: 0.423
# 7: 0.399
# 8: 0.377
# 9: 0.357
# 10: 0.34
# 11: 0.324
# 12: 0.31
# 13: 0.297
# 14: 0.285
# 15: 0.275
# 16: 0.265
# 17: 0.257
# 18: 0.249
# 19: 0.242
# 20: 0.235

# %%
load_results_and_plot("gini_threshold-0966_no_unknown_types")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.625
# 2: 0.521
# 3: 0.443
# 4: 0.382
# 5: 0.336
# 6: 0.298
# 7: 0.268
# 8: 0.244
# 9: 0.224
# 10: 0.207
# 11: 0.193
# 12: 0.18
# 13: 0.17
# 14: 0.16
# 15: 0.152
# 16: 0.145
# 17: 0.138
# 18: 0.132
# 19: 0.127
# 20: 0.122
#
# Mean recall
# 1: 0.258
# 2: 0.399
# 3: 0.485
# 4: 0.543
# 5: 0.585
# 6: 0.616
# 7: 0.639
# 8: 0.658
# 9: 0.674
# 10: 0.687
# 11: 0.699
# 12: 0.709
# 13: 0.717
# 14: 0.725
# 15: 0.732
# 16: 0.738
# 17: 0.743
# 18: 0.749
# 19: 0.753
# 20: 0.758
#
# F1 score
# 1: 0.366
# 2: 0.452
# 3: 0.463
# 4: 0.449
# 5: 0.427
# 6: 0.402
# 7: 0.378
# 8: 0.356
# 9: 0.336
# 10: 0.318
# 11: 0.302
# 12: 0.288
# 13: 0.275
# 14: 0.263
# 15: 0.252
# 16: 0.242
# 17: 0.233
# 18: 0.225
# 19: 0.217
# 20: 0.21

# %%
load_results_and_plot("gini_threshold-0966")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.547
# 2: 0.451
# 3: 0.381
# 4: 0.329
# 5: 0.289
# 6: 0.257
# 7: 0.232
# 8: 0.212
# 9: 0.195
# 10: 0.181
# 11: 0.169
# 12: 0.159
# 13: 0.15
# 14: 0.142
# 15: 0.135
# 16: 0.129
# 17: 0.123
# 18: 0.118
# 19: 0.114
# 20: 0.11
#
# Mean recall
# 1: 0.239
# 2: 0.366
# 3: 0.442
# 4: 0.494
# 5: 0.532
# 6: 0.56
# 7: 0.582
# 8: 0.601
# 9: 0.616
# 10: 0.628
# 11: 0.64
# 12: 0.65
# 13: 0.658
# 14: 0.666
# 15: 0.673
# 16: 0.679
# 17: 0.685
# 18: 0.69
# 19: 0.695
# 20: 0.7
#
# F1 score
# 1: 0.333
# 2: 0.404
# 3: 0.409
# 4: 0.395
# 5: 0.374
# 6: 0.353
# 7: 0.332
# 8: 0.314
# 9: 0.297
# 10: 0.281
# 11: 0.268
# 12: 0.255
# 13: 0.244
# 14: 0.234
# 15: 0.225
# 16: 0.217
# 17: 0.209
# 18: 0.202
# 19: 0.195
# 20: 0.189

# %%
load_results_and_plot("gini_threshold-0985")
# Out:
# 0it [00:00, ?it/s]
# Mean precision
# 1: 0.575
# 2: 0.48
# 3: 0.408
# 4: 0.354
# 5: 0.311
# 6: 0.278
# 7: 0.252
# 8: 0.231
# 9: 0.213
# 10: 0.199
# 11: 0.186
# 12: 0.176
# 13: 0.166
# 14: 0.158
# 15: 0.151
# 16: 0.145
# 17: 0.139
# 18: 0.134
# 19: 0.13
# 20: 0.126
#
# Mean recall
# 1: 0.249
# 2: 0.385
# 3: 0.466
# 4: 0.52
# 5: 0.559
# 6: 0.587
# 7: 0.61
# 8: 0.627
# 9: 0.642
# 10: 0.655
# 11: 0.666
# 12: 0.675
# 13: 0.683
# 14: 0.691
# 15: 0.697
# 16: 0.703
# 17: 0.708
# 18: 0.713
# 19: 0.718
# 20: 0.722
#
# F1 score
# 1: 0.348
# 2: 0.427
# 3: 0.435
# 4: 0.421
# 5: 0.4
# 6: 0.378
# 7: 0.357
# 8: 0.338
# 9: 0.32
# 10: 0.305
# 11: 0.291
# 12: 0.279
# 13: 0.268
# 14: 0.258
# 15: 0.249
# 16: 0.24
# 17: 0.233
# 18: 0.226
# 19: 0.22
# 20: 0.214

# %%
folder_names=["epfl_reproduction_provided_category_section_counts","epfl_reproduction-category_section_counts_with_test_set","epfl_reproduction","gini_threshold-0966"]
named_experiments=["Paper reproduction with provided category section counts","Reproduction with 2017 data, test set included in section counts","Reproduction with 2017 data","Reproduction with 2021 data"]
load_multiple_results_and_compare_by_metric(folder_names,named_experiments)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
folder_names=["gini_threshold-0966","gini_threshold-0985","gini_threshold-0966_no_unknown_types","gini_threshold-0985_no_unknown_types"]
named_experiments=["Reproduction with 2021 data","Gini threshold increased to 0.985","No unknown type articles","Gini threshold increased to 0.985 + no unknown type articles"]
load_multiple_results_and_compare_by_metric(folder_names,named_experiments)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
folder_names=["gini_threshold-0966","gini_threshold-0966_no_unknown_types"]
named_experiments=["Reproduction with 2021 data","No unknown type articles"]
load_multiple_results_and_compare_by_metric(folder_names,named_experiments)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
