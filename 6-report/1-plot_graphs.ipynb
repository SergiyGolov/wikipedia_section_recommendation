# %%
# %run ../utils/common.py
import networkx as nx

# %%
community_categories={}
with open("../data/categories_splitted_into_communities.json", "r") as f_in:
    for line in f_in:
        json_line=json.loads(line)
        community_categories[json_line['community_id']]=json_line['categories']

# %%
community_categories[23]
# Out:
# ['Buildings_and_structures_in_Campinas',
#  'Music_venues_completed_in_1886',
#  'Music_venues_in_Montreal',
#  "UC_Riverside_Highlanders_women's_volleyball",
#  'Olympic_freestyle_skiing_venues',
#  'Shopping_malls_in_Omaha,_Nebraska',
#  'Casinos_completed_in_1994',
#  'Shopping_malls_in_Kern_County,_California',
#  'Music_venues_in_Ottawa',
#  'Theatres_in_Sofia',
#  'Theatres_in_Brooklyn',
#  'Skyscrapers_in_Lisbon',
#  'Bosnian-American_culture_in_Missouri',
#  'South_Park_(Downtown_Los_Angeles)',
#  'Theatres_in_the_Bronx',
#  'Cleveland_Browns_stadiums',
#  'Gymnastics_venues_in_California',
#  'Wrestling_venues_in_California',
#  'Theatre_companies_in_Pittsburgh',
#  'Waterhead,_Greater_Manchester',
#  'Sports_venues_in_Fukushima_Prefecture',
#  'Sports_venues_in_Nagano_Prefecture',
#  'Sports_venues_in_Gunma_Prefecture',
#  'Velodromes_in_Switzerland',
#  'Barra_Olympic_Park',
#  'Ski_areas_and_resorts_in_France',
#  'Music_venues_completed_in_1899',
#  'Soccer_venues_in_Los_Angeles',
#  'Basketball_venues_in_Italy',
#  'Geography_of_San_Francisco',
#  'Venues_of_the_2002_Winter_Olympics',
#  'Football_venues_in_Kharkiv_Oblast',
#  'Theatres_on_the_National_Register_of_Historic_Places_in_Virginia',
#  '1860_establishments_in_Croatia',
#  'USL_Championship_stadiums',
#  'Tourist_attractions_in_Hamilton_County,_Indiana',
#  "LSU_Tigers_women's_soccer_venues",
#  'Sports_venues_demolished_in_1995',
#  'Demolished_theatres_in_Illinois',
#  'Sports_venues_in_Highland_(council_area)',
#  'National_Register_of_Historic_Places_in_Tuscaloosa_County,_Alabama',
#  'Theatres_in_Vancouver',
#  'Sports_venues_completed_in_1916',
#  'Cinemas_and_movie_theaters_in_Pennsylvania',
#  'Railway_lines_closed_in_2004',
#  'Defunct_indoor_arenas_in_Pennsylvania',
#  'Wrestling_venues_in_New_Orleans',
#  'Defunct_retractable-roof_stadiums',
#  'Performing_arts_centers_in_Ukraine',
#  'Music_venues_completed_in_1997',
#  'Defunct_indoor_lacrosse_venues_in_the_United_States',
#  'Sports_venues_demolished_in_2012',
#  'Arts_centers_in_Ukraine',
#  'LSU_Tigers_golf_clubs_and_courses',
#  'Sports_venues_in_Epirus',
#  'AFC_Ajax_facilities',
#  'Art_Nouveau_architecture_in_Northern_Ireland',
#  'Netball_venues_in_Scotland',
#  'Sports_venues_completed_in_2015',
#  'World_Football_League_venues',
#  'Commercial_buildings_completed_in_1973',
#  'Misericórdia',
#  'Baseball_venues_in_Michigan',
#  'Baseball_venues_in_Massachusetts',
#  'Sports_venues_completed_in_1929',
#  'Olympic_basketball_venues',
#  'Basketball_venues_in_South_Korea',
#  'Venues_of_the_1956_Summer_Olympics',
#  'LSU_Lady_Tigers_golf_clubs_and_courses',
#  'SoDo,_Seattle',
#  'Olympic_swimming_venues',
#  'Handball_venues_in_the_United_States',
#  'Art_Deco_architecture_in_Mexico',
#  'California_League_ballparks',
#  'Soccer_venues_in_San_Francisco',
#  'Tekkeköy',
#  'Baseball_venues_in_New_Jersey',
#  'Art_Deco_architecture_in_Portugal',
#  'Bridges_in_Pisa',
#  'Sports_venues_in_Hamburg',
#  'Rock_music_venues',
#  'Defunct_horse_racing_venues_in_Spain',
#  'Wrestling_venues_in_San_Francisco',
#  'National_Register_of_Historic_Places_in_Jefferson_County,_Florida',
#  'Olympic_baseball_venues',
#  'Sports_venues_completed_in_1871',
#  'Sports_venues_in_Raleigh,_North_Carolina',
#  "Cal_Poly_Mustangs_women's_beach_volleyball_venues",
#  'Skyscrapers_in_Shinjuku',
#  'Sports_in_Traverse_City,_Michigan',
#  'Soccer_in_the_San_Francisco_Bay_Area',
#  'Museums_in_Kern_County,_California',
#  'Murals_in_North_Korea',
#  'Sports_venues_in_Sheffield',
#  'Texas_Tech_Lady_Raiders_basketball_venues',
#  'Sport_in_Setúbal',
#  'Sports_in_Wausau,_Wisconsin',
#  '1991_disestablishments_in_New_Jersey',
#  'Olympic_snowboarding_venues',
#  'Baseball_venues_in_Maine',
#  'Ski_stadiums_in_Norway',
#  'Beaches_of_Cook_County,_Illinois',
#  'Soccer_venues_in_Kentucky',
#  'Sports_venues_in_Alberta',
#  'Bodies_of_water_of_Oakland_County,_Michigan',
#  'Sports_venues_in_Gibraltar',
#  'Volleyball_venues_in_Indiana',
#  '1920s_establishments_in_Virginia',
#  'Sports_in_Wisconsin_Rapids,_Wisconsin',
#  'Volleyball_venues_in_Croatia',
#  'Boxing_gyms_in_the_United_States',
#  'UEFA_competition_navigational_boxes',
#  'Theatres_on_the_National_Register_of_Historic_Places_in_New_Jersey',
#  'Sports_venues_in_Okinawa_Prefecture',
#  'Cinemas_and_movie_theaters_in_Omaha,_Nebraska',
#  'Indoor_ice_hockey_venues_in_Croatia',
#  'Boxing_clubs_in_the_United_States',
#  'National_Register_of_Historic_Places_in_Lee_County,_Florida',
#  'Canadian_Premier_League_stadiums',
#  'Galatasaray_S.K._facilities',
#  'Demolished_buildings_and_structures_in_Scotland',
#  'Mixed_martial_arts_venues_in_New_York_(state)',
#  'LSU_Tigers_softball_venues',
#  'Museums_in_Alpes-Maritimes',
#  '2017_European_Athletics_Indoor_Championships',
#  'Sports_venues_in_Manchester',
#  'Ballrooms_in_Australia',
#  'Rugby_union_stadiums_in_Georgia_(country)',
#  'Sports_venues_in_Placer_County,_California',
#  'Wrestling_venues_in_New_York_(state)',
#  'Demolished_sports_venues_in_Georgia_(U.S._state)',
#  "World's_fair_architecture_in_Barcelona",
#  'International_Professional_Hockey_League_venues',
#  'Defunct_association_football_venues_in_Northern_Ireland',
#  'Sports_venues_in_Belo_Horizonte',
#  'Sports_venues_completed_in_2019',
#  'Carolina_League_ballparks',
#  'Music_museums_in_California',
#  'Defunct_soccer_venues_in_Canada',
#  'College_tennis_venues_in_the_United_States',
#  'Performing_arts_centers_in_Iowa',
#  'LSU_Tigers_tennis_venues',
#  'LSU_Lady_Tigers_tennis_venues',
#  'Netball_venues_in_England',
#  'Buddhist_temples_in_Fukuoka_Prefecture',
#  'Defunct_football_venues_in_Germany',
#  'Sports_venues_completed_in_1925',
#  'Sports_venues_in_Brisbane',
#  'Rugby_union_stadiums_in_Germany',
#  'Venues_of_the_2015_Parapan_American_Games',
#  'Erie_SeaWolves',
#  '1967_establishments_in_Hungary',
#  'Star_Entertainment_Group',
#  'LSU_Tigers_baseball_venues',
#  'Miami_Marlins_stadiums',
#  'Sports_venues_in_Sacramento,_California',
#  'Texas_Tech_Red_Raiders_basketball_venues',
#  'Music_venues_completed_in_1981',
#  'Demolished_buildings_and_structures_in_the_West_Midlands_(county)',
#  '1913_establishments_in_Austria',
#  'Miami_Marlins_spring_training_venues',
#  'Sports_venues_in_Valencia',
#  'Sports_venues_completed_in_1936',
#  'University_of_California,_Davis_campus',
#  'Towers_in_Washington,_D.C.',
#  'Defunct_football_venues_in_Switzerland',
#  'Streets_in_Portland,_Oregon',
#  'Theatres_in_Kristiansand',
#  'Lamar_Cardinals_and_Lady_Cardinals_sports_venues',
#  'New_Hartford,_Connecticut',
#  'Sports_venues_in_Munich',
#  'Buildings_and_structures_demolished_in_1890',
#  'LSU_Tigers_football_venues',
#  'Florida_State_League_ballparks',
#  'Theatres_in_Iran',
#  'Landforms_of_Västmanland_County',
#  'Washington_Senators_(1961–1971)_stadiums',
#  'Defunct_speedway_venues_in_Australia',
#  'Buildings_and_structures_in_Salamanca_District,_Madrid',
#  'Sports_venues_in_Bradford',
#  'Rugby_union_stadiums_in_Italy',
#  'Protected_areas_of_Floyd_County,_Indiana',
#  'Baseball_venues_in_Nevada',
#  'Theatres_completed_in_1981',
#  'Ice_hockey_venues_in_Sweden',
#  'Softball_venues_in_New_Zealand',
#  '2010_FIFA_World_Cup_stadiums',
#  'Baseball_venues_in_Iowa',
#  'Pedestrian_bridges_in_Perth,_Western_Australia',
#  'South_Alabama_Jaguars_sports_venues',
#  'Presidents_Cup_venues',
#  'Leather_bars_and_clubs',
#  'Theatres_on_the_National_Register_of_Historic_Places_in_Arizona',
#  'LSU_Tigers_and_Lady_Tigers_sports_venues',
#  'Defunct_speedway_venues_in_Scotland',
#  'Midwest_League_ballparks',
#  'Shopping_malls_in_Chicago',
#  'Association_football_training_grounds_in_Montenegro',
#  '2007_disestablishments_in_Montana',
#  'Defunct_sports_venues_in_Maryland',
#  'Defunct_speedway_venues_in_Wales',
#  'Music_venues_in_Washington,_D.C.',
#  'Nightclubs_in_Washington,_D.C.',
#  'Speedway_venues_in_Wales',
#  'Parks_on_the_National_Register_of_Historic_Places_in_Chicago',
#  'Venues_of_the_2024_Summer_Olympics',
#  'Swimming_venues_in_Turkey',
#  'Football_venues_in_Stockholm',
#  'Cricket_grounds_in_England',
#  'University_and_college_buildings_completed_in_1885',
#  '1978_disestablishments_in_Rhode_Island',
#  'Theatres_completed_in_1968',
#  'Defunct_indoor_arenas_in_California',
#  "World's_fair_architecture_in_Montreal",
#  'Buildings_and_structures_in_Gwacheon',
#  'American_football_venues_in_Japan',
#  'Church_of_England_church_buildings_in_the_London_Borough_of_Bromley',
#  'Music_venues_completed_in_1979',
#  'County_courthouses_in_New_Jersey',
#  'Indoor_arenas_in_Ontario',
#  'Buildings_and_structures_in_Chamartín_District,_Madrid',
#  'Indoor_arenas_in_Quebec',
#  'Pubs_in_the_London_Borough_of_Lambeth',
#  'Theatres_in_Cluj-Napoca',
#  'West_End,_Boston',
#  'Defunct_indoor_arenas_in_Florida',
#  'Buildings_and_structures_in_Zenica',
#  'Theatres_in_Iași',
#  'Baseball_venues_in_East_Texas',
#  'Brooklyn_Nets_venues',
#  'Olympic_karate_venues',
#  'Sports_venues_in_Jönköping',
#  'Gay_culture_in_Oregon',
#  'Sports_venues_in_Malmö',
#  'Historic_American_Landscapes_Survey_in_Washington,_D.C.',
#  'Sports_venues_in_Wichita,_Kansas',
#  'Sports_venues_in_Borås',
#  'Former_buildings_and_structures_in_Madrid',
#  'School_buildings_completed_in_2005',
#  'Theatres_completed_in_1929',
#  'Football_venues_in_East_Germany',
#  'Basketball_venues_in_Hungary',
#  'Defunct_basketball_venues',
#  'Theatres_in_Bratislava',
#  'National_Monuments_in_Illinois',
#  'Art_Deco_architecture_in_Ohio',
#  'South_Atlantic_League_ballparks',
#  'Parks_in_Miami',
#  'Defunct_amusement_parks_in_New_York_(state)',
#  'Indoor_arenas_in_Alberta',
#  'Armories_in_the_United_States',
#  'Bus_stations_in_Perth,_Western_Australia',
#  'National_Basketball_Association_venues',
#  'Defunct_indoor_arenas_in_Texas',
#  'Indoor_arenas_in_Saskatchewan',
#  'Boxing_venues_in_Russia',
#  'Shopping_centres_in_Perth,_Western_Australia',
#  'Indoor_arenas_in_British_Columbia',
#  'University_and_college_buildings_completed_in_1973',
#  'Sports_venues_in_Perth,_Western_Australia',
#  'Indoor_arenas_in_Nova_Scotia',
#  'Theatres_in_Donetsk',
#  'Defunct_entertainment_venues',
#  'Tennis_venues_in_California',
#  'Boxing_venues_in_Mexico',
#  'Textile_companies_of_Spain',
#  'Boxing_venues_in_Germany',
#  'Tourist_attractions_in_Neath_Port_Talbot',
#  'Sports_venues_demolished_in_1912',
#  'Theatres_in_the_London_Borough_of_Wandsworth',
#  'Venues_of_the_2020_Winter_Youth_Olympics',
#  'Music_venues_completed_in_2001',
#  'Old_Deer_Park',
#  'Indoor_arenas_in_Prince_Edward_Island',
#  'Botanical_gardens_in_Arizona',
#  'American_football_venues_in_California',
#  'Defunct_association_football_venues_in_the_Republic_of_Ireland',
#  'Sports_venues_in_Trondheim',
#  'Indoor_arenas_in_New_Brunswick',
#  'Music_venues_completed_in_2005',
#  'Suspension_structures',
#  'Music_venues_completed_in_2004',
#  'Defunct_rugby_league_venues_in_New_Zealand',
#  'Sports_venues_demolished_in_1941',
#  'Defunct_indoor_arenas_in_Illinois',
#  'Olympic_volleyball_venues',
#  'Sports_venues_completed_in_2001',
#  'Defunct_rugby_league_venues_in_Australia',
#  'Demolished_buildings_and_structures_in_Brooklyn',
#  'Sports_venues_completed_in_2003',
#  'Sports_venues_completed_in_2004',
#  'Sports_venues_completed_in_2005',
#  'Sports_venues_in_Eugene,_Oregon',
#  'Indoor_arenas_in_Manitoba',
#  'Boxing_venues_in_Canada',
#  'Motorsport_venues_in_Victoria_(Australia)',
#  'Defunct_motorsport_venues_in_Australia',
#  'Commercial_buildings_completed_in_1935',
#  '1961_disestablishments_in_Illinois',
#  'Demolished_buildings_and_structures_in_Idaho',
#  'Boxing_venues_in_Spain',
#  'Northwest_League_ballparks',
#  'Boxing_venues_in_France',
#  'Olympic_gymnastics_venues',
#  'Sports_venues_in_Athens',
#  'Sports_venues_in_Helsinki',
#  'Low-A_Southeast_ballparks',
#  'School_buildings_completed_in_1819',
#  'Demolished_buildings_and_structures_in_Queens,_New_York',
#  '1786_establishments_in_the_Russian_Empire',
#  'Sports_venues_in_Broward_County,_Florida',
#  'Sports_venues_in_Toronto',
#  'Music_venues_completed_in_1978',
#  'Portsmouth,_Portland,_Oregon',
#  'Music_venues_in_Manchester',
#  'Commercial_buildings_completed_in_1859',
#  'UT_Arlington_Mavericks_softball',
#  'Cinemas_and_movie_theaters_in_Hollywood,_California',
#  'National_Register_of_Historic_Places_in_Portage_County,_Ohio',
#  'Defunct_sports_venues_in_Virginia',
#  'Indoor_arenas_in_Newfoundland_and_Labrador',
#  'NASCAR_races_at_Indianapolis_Motor_Speedway',
#  'Indoor_arenas_in_South_Carolina',
#  'Theatres_in_Albania',
#  'Pan_American_Games_handball_venues',
#  'Theatres_completed_in_1782',
#  '1957_establishments_in_Bosnia_and_Herzegovina',
#  'Nightclubs_in_Seattle',
#  'Sports_venues_demolished_in_1964',
#  'Football_venues_in_Belarus',
#  'Appalachian_League_ballparks',
#  'Economy_of_Dorset',
#  'High_school_football_venues_in_California',
#  'Former_cinemas_in_Manchester',
#  'Grammy_Award_venues',
#  'Theatres_in_the_London_Borough_of_Croydon',
#  'Indoor_arenas_in_West_Virginia',
#  'Soccer_venues_in_the_United_States_Virgin_Islands',
#  '1980_architecture',
#  'Buildings_and_structures_demolished_in_2003',
#  'Ski_areas_and_resorts_in_South_Australia',
#  'Parks_and_commons_in_Blackpool',
#  'Entertainment_venues_in_Brooklyn',
#  'Buildings_and_structures_in_Stockholm_County',
#  'Arizona_League_ballparks',
#  'Venues_of_the_1932_Summer_Olympics',
#  'Post_office_buildings_in_the_United_Kingdom',
#  '1946_disestablishments_in_Idaho',
#  'Softball_venues_in_Texas',
#  'Evangelical_churches_in_Idaho',
#  'Rugby_union_stadiums_in_Singapore',
#  'Tourist_attractions_in_Adams_County,_Colorado',
#  'Indoor_arenas_in_Tennessee',
#  'Buildings_and_structures_in_Adams_County,_Colorado',
#  'Commercial_buildings_completed_in_1933',
#  'Sports_venues_in_Salt_Lake_County,_Utah',
#  'Sports_venues_in_County_Londonderry',
#  'Indoor_arenas_in_Idaho',
#  'Indoor_arenas_in_New_Hampshire',
#  'Theatres_on_the_National_Register_of_Historic_Places_in_Wisconsin',
#  'Sports_venues_in_Anaheim,_California',
#  'Athletics_(track_and_field)_venues_in_Nepal',
#  'Lists_of_music_venues',
#  'Rugby_union_stadiums_in_Indiana',
#  'Sports_venues_in_Ulsan',
#  'Sports_venues_in_County_Antrim',
#  'Horse_racing_venues_in_California',
#  'Tourist_attractions_in_Jefferson_County,_Florida',
#  'Theatres_completed_in_1885',
#  'Olympic_football_venues',
#  'College_soccer_venues_in_California',
#  'Sports_venues_in_County_Tyrone',
#  'Sports_venues_demolished_in_1952',
#  'Concert_halls_in_Michigan',
#  'Theatres_completed_in_1978',
#  'Art_Deco_architecture_in_New_Jersey',
#  'Tourist_attractions_in_New_Kent_County,_Virginia',
#  'Theatres_on_the_National_Register_of_Historic_Places_in_Arkansas',
#  'Heliports_in_New_York_(state)',
#  'Sants-Montjuïc',
#  'Boxing_venues_in_the_United_States',
#  'Indoor_arenas_in_Hawaii',
#  'Houses_completed_in_1975',
#  'Historic_district_contributing_properties_in_Tennessee',
#  'Tourist_attractions_in_Prince_William_County,_Virginia',
#  'Sports_venues_in_Zagreb',
#  '2006_FIFA_World_Cup_stadiums',
#  'Music_venues_completed_in_1977',
#  'Parks_established_in_1867',
#  'Theatres_completed_in_1859',
#  'NASCAR_races_at_Road_America',
#  'Cleveland_Chase_Brassmen',
#  'Theatres_completed_in_1977',
#  'Gulf_Coast_League_ballparks',
#  'Sports_venues_in_Aberdeenshire',
#  'Monuments_and_memorials_in_North_Yorkshire',
#  'Music_venues_in_Sweden',
#  'Boston_Cannons_venues',
#  'Theatres_in_Turkey',
#  'Geography_of_Almaty',
#  'Football_Alliance_venues',
#  'Sports_venues_in_Kuala_Lumpur',
#  '1885_establishments_in_Croatia',
#  'Olympic_curling_venues',
#  '1974_FIFA_World_Cup_stadiums',
#  'Defunct_Midwest_League_ballparks',
#  'Sports_venues_in_County_Kerry',
#  'Music_venues_completed_in_1976',
#  'Casinos_in_Atlantic_City,_New_Jersey',
#  'UEFA_Euro_2024_stadiums',
#  '2002_FIFA_World_Cup_stadiums_in_South_Korea',
#  'Culture_of_Fullerton,_California',
#  'Buildings_and_structures_in_Oberhausen',
#  'Saenger_theatres',
#  'Sports_venues_in_Sarajevo',
#  'Texas_Longhorns_basketball',
#  'Ruins_in_Madrid',
#  'Middlesbrough_F.C._facilities',
#  'Theatres_in_Winnipeg',
#  '2002_FIFA_World_Cup_stadiums_in_Japan',
#  'Redeveloped_ports_and_waterfronts_in_Australia',
#  'Sports_venues_in_Vancouver',
#  'Tourist_attractions_in_McHenry_County,_Illinois',
#  'Gainsborough_Ward,_Ipswich',
#  'XFL_(2020)_venues',
#  '1982_establishments_in_Bosnia_and_Herzegovina',
#  '1926_architecture',
#  '2015_establishments_in_Hawaii',
#  'Buildings_and_structures_in_Santiago_del_Estero_Province',
#  '1651_establishments_in_Norway',
#  'English_Football_League_venues',
#  'Sarrià-Sant_Gervasi',
#  'Indoor_arenas_in_Arizona',
#  'Tourist_infrastructure_in_Queensland',
#  'Buildings_and_structures_in_Usera_District,_Madrid',
#  '1899_establishments_in_Newfoundland',
#  'Main_Beach,_Queensland',
#  'Buildings_and_structures_in_San_Blas-Canillejas_District,_Madrid',
#  'Sports_venues_in_Montgomery,_Alabama',
#  'California_Surf_sports_facilities',
#  'Olympic_handball_venues',
#  'Sports_venues_in_Tamaulipas',
#  'Soccer_venues_in_South_Africa',
#  'Double-A_South_ballparks',
#  'Sports_venues_in_Central_District_(Israel)',
#  'Sports_venues_in_Tel_Aviv_District',
#  'Sports_venues_in_Southern_District_(Israel)',
#  'Music_venues_in_Paris',
#  'Double-A_Northeast_ballparks',
#  'Towson_Tigers_sports_venues',
#  'Auckland_volcanic_field',
#  'Horse_racing_venues_in_Canada',
#  'Double-A_Central_ballparks',
#  'Sports_venues_in_Mato_Grosso',
#  'LGBT_drinking_establishments_in_Washington_(state)',
#  'Casinos_in_West_Virginia',
#  'Judo_venues',
#  'Sports_venues_completed_in_1961',
#  'Music_venues_in_Kazakhstan',
#  'Sports_venues_completed_in_1963',
#  'Sports_venues_completed_in_1965',
#  'Sports_venues_completed_in_1966',
#  'Sports_venues_completed_in_1967',
#  'Rugby_union_stadiums_in_Indonesia',
#  'Sports_venues_in_Chattanooga,_Tennessee',
#  '20th_century_in_Arlington,_Texas',
#  'Sports_venues_completed_in_1937',
#  'National_Basketball_League_(Australia)_venues',
#  'Bank_of_America_buildings',
#  'Music_venues_completed_in_1937',
#  'Community_buildings_in_Queensland',
#  'Tennis_venues_in_Russia',
#  '1941_disestablishments_in_Newfoundland',
#  'Theatres_in_Kazakhstan',
#  'LGBT_drinking_establishments_in_Oregon',
#  'Sports_venues_in_San_Antonio',
#  'Buildings_and_structures_completed_in_1887',
#  '1936_establishments_in_Saskatchewan',
#  'Sports_venues_in_the_Quad_Cities',
#  'Lacrosse_museums_and_halls_of_fame',
#  'Stripped_Classical_architecture_in_the_United_States',
#  'New_York_Yankees_spring_training_venues',
#  '2006_establishments_in_Uruguay',
#  'Music_venues_in_Sydney',
#  'Sports_venues_in_Edinburgh',
#  'Tourist_attractions_in_Ellsworth_County,_Kansas',
#  'Sports_venues_in_Fort_Worth,_Texas',
#  'Football_venues_in_Rio_de_Janeiro_(city)',
#  'Sports_venues_completed_in_1926',
#  'Sports_venues_in_Rio_de_Janeiro_(city)',
#  'Association_football_venues_in_County_Down',
#  'Buildings_and_structures_in_Green_Lake_County,_Wisconsin',
#  'Sports_venues_in_Maricopa_County,_Arizona',
#  '1998_FIFA_World_Cup_stadiums',
#  '1972_disestablishments_in_Missouri',
#  '2015_establishments_in_West_Virginia',
#  'Demolished_hotels_in_New_Jersey',
#  'Sports_venues_in_County_Down',
#  '2010_disestablishments_in_Kansas',
#  'Theatres_completed_in_1974',
#  'Sports_venues_in_Austin,_Texas',
#  'University_of_Oklahoma_campus',
#  'Football_venues_in_Argentina',
#  '1938_FIFA_World_Cup_stadiums',
#  'Los_Angeles_Angels_stadiums',
#  'Philadelphia_Atoms_sports_facilities',
#  '1915_architecture',
#  'Art_Nouveau_architecture_in_New_York_(state)',
#  'Geography_of_Blackpool',
#  'Music_venues_completed_in_1971',
#  'Football_venues_in_Austria',
#  'Music_venues_in_Tennessee',
#  'Theatres_completed_in_1971',
#  'Art_Nouveau_architecture_in_Chicago',
#  'Mountain_biking_venues_in_Canada',
#  'Music_venues_completed_in_1970',
#  'Sengkang_Sports_Centre',
#  'Hollywood_Stars',
#  'Music_venues_in_Kansas',
#  '1957_disestablishments_in_Oregon',
#  "Illinois_Fighting_Illini_men's_gymnastics_venues",
#  '1911_architecture',
#  'Rugby_union_stadiums_in_Washington,_D.C.',
#  '1994_FIFA_World_Cup_stadiums',
#  'Florida_Gators_baseball_venues',
#  "Illinois_Fighting_Illini_women's_gymnastics_venues",
#  'Sports_venues_in_West_Dunbartonshire',
#  '1901_disestablishments_in_Ohio',
#  'Soccer_venues_in_Canada',
#  'Fires_in_Ukraine',
#  'Football_venues_in_Colombia',
#  'Stadiums_in_Wales',
#  'Sports_venues_in_County_Wexford',
#  'Sports_venues_in_County_Wicklow',
#  'Football_venues_in_Croatia',
#  'Chicago_Maroons_basketball',
#  'European-American_culture_in_Portland,_Oregon',
#  'Sports_venues_in_County_Westmeath',
#  'Sports_venues_in_Palmerston_North',
#  'Sports_venues_in_El_Paso,_Texas',
#  'Football_venues_in_the_Czech_Republic',
#  'Convention_centres_in_Romania',
#  'Sports_venues_in_County_Sligo',
#  '1990_FIFA_World_Cup_stadiums',
#  'Historic_American_Landscapes_Survey_in_Indiana',
#  'Concert_halls_in_Romania',
#  'Sports_venues_in_County_Mayo',
#  'Sports_venues_in_County_Louth',
#  'Tourist_attractions_in_Santa_Rosa,_California',
#  'Atlanta_Dream_venues',
#  'Sports_venues_in_County_Carlow',
#  'Unbuilt_stadiums_in_the_United_States',
#  'Defunct_rugby_union_stadiums_in_Australia',
#  '1934_FIFA_World_Cup_stadiums',
#  'Indoor_arenas_in_Taiwan',
#  'Sports_venues_in_Waco,_Texas',
#  '1914_establishments_in_Mississippi',
#  'Baseball_venues_in_Oregon',
#  'Buildings_and_structures_in_Wasatch_County,_Utah',
#  'Towers_in_Ontario',
#  'Venues_of_the_2011_Pan_American_Games',
#  'Santa_Clara_Broncos_basketball',
#  '1986_FIFA_World_Cup_stadiums',
#  'SMU_Mustangs_basketball',
#  'Basketball_venues_in_Washington,_D.C.',
#  'Lists_of_Canadian_sportspeople',
#  'Baseball_venues_in_North_Carolina',
#  'Concert_halls_in_Illinois',
#  'Bases_of_the_Swedish_Air_Force',
#  'Proposed_indoor_arenas_in_the_United_States',
#  'Velodromes_in_Croatia',
#  'Sports_venues_in_Corpus_Christi,_Texas',
#  'Sports_venues_in_Bakersfield,_California',
#  'Parks_in_Oak_Cliff',
#  'National_Basketball_League_of_Canada_arenas',
#  "World's_fair_architecture_in_Australia",
#  'Former_sports_venues_in_Madrid',
#  'Arts_centers_in_Utah',
#  '1970_FIFA_World_Cup_stadiums',
#  'Music_venues_in_Paraguay',
#  '2001_disestablishments_in_New_Mexico',
#  '1979_Davis_Cup',
#  'Demolished_sports_venues_in_Washington_(state)',
#  'Sports_venues_demolished_in_2000',
#  'Basketball_venues_in_Taiwan',
#  '1982_FIFA_World_Cup_stadiums',
#  'Tourist_attractions_in_Boone_County,_Kentucky',
#  'Music_venues_in_Portland,_Maine',
#  'Pyramids_in_China',
#  '1894_establishments_in_New_Mexico_Territory',
#  'Swedish_Bandy_Final_venues',
#  'Defunct_sports_venues_in_Arkansas',
#  'American_football_venues_in_Los_Angeles',
#  'Chinatown,_Philadelphia',
#  'Caturiges',
#  'Sports_venues_in_Richmond,_Virginia',
#  'Training_installations_of_the_United_States_Navy',
#  'Parks_in_Sarasota_County,_Florida',
#  'Tourist_attractions_in_Loudoun_County,_Virginia',
#  'Sports_venues_in_Beaumont,_Texas',
#  'Los_Angeles_Aztecs_sports_facilities',
#  "Loew's_Theatres_buildings_and_structures",
#  'Cultural_landscapes_of_Australia',
#  'Sports_venues_in_Inglewood,_California',
#  'Sports_venues_in_Ogden,_Utah',
#  'Sports_venues_completed_in_1890',
#  'Defunct_jazz_clubs_in_the_United_States',
#  'Demolished_sports_venues_in_Louisiana',
#  'Buildings_and_structures_in_Östergötland_County',
#  'Professional_wrestling_venues_in_Mexico',
#  'International_style_architecture_in_Illinois',
#  'Snooker_venues',
#  'Ice_hockey_venues_in_California',
#  'Community_centres_in_the_United_Kingdom',
#  'Lower_North_Philadelphia',
#  'Sports_venues_in_Long_Beach,_California',
#  '2015_disestablishments_in_South_Carolina',
#  'Sports_venues_in_College_Station,_Texas',
#  'Defunct_sports_venues_in_Wisconsin',
#  'Cajun_restaurants',
#  'Anaheim_Ducks_arenas',
#  'Defunct_rugby_union_venues_in_England',
#  'Defunct_rugby_union_venues',
#  'Convention_centers_in_Mexico',
#  'Auburn_Tigers_football_venues',
#  'Defunct_National_Basketball_League_(Australia)_venues',
#  'Casinos_completed_in_1986',
#  'Sports_venues_in_Durham,_North_Carolina',
#  'Restaurants_disestablished_in_1971',
#  'Sports_venues_in_Omaha_metro_area',
#  'Sports_venues_in_Yolo_County,_California',
#  'Sports_venues_in_İzmir',
#  'Sports_venues_in_Montreal',
#  '1970_mass_shootings_in_the_United_States',
#  'Shinty_venues',
#  'Georgia_Bulldogs_football_venues',
#  'Parks_in_İzmir',
#  'Sports_venues_in_Baton_Rouge,_Louisiana',
#  'Sports_venues_in_Laredo,_Texas',
#  'Rugby_union_in_County_Westmeath',
#  'Sports_in_Lynchburg,_Virginia',
#  'Alabama_Crimson_Tide_football_venues',
#  'Ski_stadiums_in_Canada',
#  'Buildings_and_structures_in_Gävleborg_County',
#  'Parks_on_the_National_Register_of_Historic_Places_in_Missouri',
#  '1973_disestablishments_in_New_Jersey',
#  'Venues_of_the_1960_Summer_Olympics',
#  'Buildings_and_structures_in_Västernorrland_County',
#  'Art_museums_and_galleries_in_Douala',
#  'Broadway_theatres',
#  'Buildings_and_structures_in_Västerbotten_County',
#  'Tourist_attractions_in_Richland_County,_Ohio',
#  'American_football_venues_in_Georgia_(U.S._state)',
#  'Funicular_railways_in_Canada',
#  'Sports_venues_in_Worcester,_Massachusetts',
#  'Sports_venues_in_Fresno,_California',
#  'Olympic_stadiums',
#  'Casinos_completed_in_1998',
#  'Sports_venues_in_West_Yorkshire',
#  'Tourist_attractions_in_Fukuoka',
#  'Sports_venues_in_Shizuoka_Prefecture',
#  'Theatres_in_Tokyo',
#  'Indoor_arenas_in_Uruguay',
#  'Sports_venues_in_Arlington,_Texas',
#  'Event_venues_established_in_1952',
#  'Defunct_Australian_rules_football_grounds',
#  'Defunct_Australian_Football_League_grounds',
#  'Sports_venues_completed_in_1735',
#  'Sports_venues_completed_in_1765',
#  'Stadiums_in_Abruzzo',
#  'School_buildings_completed_in_2017',
#  'Event_venues_established_in_1984',
#  'Waseda_University_buildings',
#  '1970_establishments_in_Idaho',
#  '2014_establishments_in_Alaska',
#  'Event_venues_established_in_1988',
#  'Theatres_completed_in_1941',
#  'Athletics_(track_and_field)_venues_in_Canada',
#  'Event_venues_established_in_1986',
#  'Modernist_architecture_in_Washington_(state)',
#  'Sports_venues_in_Havana',
#  'Event_venues_established_in_1985',
#  'International_style_architecture_in_Massachusetts',
#  'Event_venues_established_in_1983',
#  'Athletics_(track_and_field)_venues_in_Denmark',
#  'Event_venues_established_in_1982',
#  'Athletics_(track_and_field)_venues_in_France',
#  'Houston_Cougars_football_venues',
#  'Event_venues_established_in_1979',
#  'Goth_venues',
#  'Theatre_in_Dallas',
#  'Dojos',
#  'Sports_venues_in_Bergen',
#  'IMSA_GT_Championship_circuits',
#  'Theatres_in_New_Orleans',
#  'American_Le_Mans_Series_circuits',
#  'Ski_jumping_venues_in_Austria',
#  "Louisville_Cardinals_men's_basketball_venues",
#  'Event_venues_established_in_1974',
#  'Theatres_in_Pittsburgh',
#  'Baseball_venues_in_Nebraska',
#  'Event_venues_established_in_1970',
#  'Defunct_football_venues_in_Scotland',
#  'Cricket_grounds_in_Japan',
#  'Football_venues_in_Denmark',
#  'Sports_venues_in_Fukuoka_Prefecture',
#  'Convention_centres_in_Canada',
#  'Brutalist_architecture_in_Virginia',
#  'Romanian_opera_companies',
#  'Defunct_soccer_venues_in_Australia',
#  'Event_venues_established_in_1968',
#  'Rugby_union_stadiums_in_London',
#  'Multi-purpose_stadiums_in_Belgium',
#  'Tennis_venues_in_Florida',
#  'Washington_Senators_(1901–1960)_stadiums',
#  'Rugby_league_stadiums_in_London',
#  'Professional_wrestling_venues_in_Indiana',
#  'Sports_venues_completed_in_1913',
#  'Swedish_opera_companies',
#  'Tourist_attractions_in_Lackawanna_County,_Pennsylvania',
#  '1864_establishments_in_Utah_Territory',
#  'Government_buildings_completed_in_1741',
#  'Sports_venues_in_Taipei',
#  'Event_venues_established_in_1960',
#  '1968_Davis_Cup',
#  'Sports_venues_completed_in_1734',
#  'Soccer_venues_in_Montreal',
#  'Sports_venues_completed_in_1782',
#  'Music_venues_completed_in_1904',
#  '2005_UCI_Track_Cycling_World_Championships',
#  'Music_venues_completed_in_1913',
#  '1958_establishments_in_Latvia',
#  'Sports_venues_in_Northumberland',
#  'Defunct_sports_venues_in_Canada',
#  'Baseball_in_Waco,_Texas',
#  'Event_venues_established_in_1929',
#  'Sports_venues_in_the_New_York_metropolitan_area',
#  'FIBA_EuroBasket_2015_venues',
#  'Event_venues_established_in_1909',
#  'Sports_venues_completed_in_1837',
#  'Modernist_architecture_in_Georgia_(U.S._state)',
#  'Event_venues_established_in_1899',
#  'Sports_venues_in_Abilene,_Texas',
#  'Ski_areas_and_resorts_in_Alberta',
#  'Sports_venues_in_East_Dunbartonshire',
#  'Sports_venues_completed_in_1783',
#  'Soccer_venues_in_Manitoba',
#  'Art_Deco_architecture_in_Wisconsin',
#  'Retail_markets_in_Guyana',
#  'Cricket_grounds_in_East_Sussex',
#  'Geography_of_Atlantic_County,_New_Jersey',
#  'Event_venues_established_in_1920',
#  'American_football_venues_in_North_Dakota',
#  'Defunct_football_venues_in_Wales',
#  'Theatres_in_Boston',
#  'Casinos_in_New_York_(state)',
#  'Football_venues_in_London',
#  'American_football_venues_in_South_Dakota',
#  'Ski_jumping_venues_in_Norway',
#  'Soccer_venues_in_New_Brunswick',
#  'International_style_architecture_in_Ohio',
#  '1957_disestablishments_in_California',
#  'Radio_masts_and_towers_in_the_United_States',
#  'Defunct_football_venues_in_Japan',
#  'American_football_venues_in_Hawaii',
#  'Volleyball_venues_in_Texas',
#  'American_football_venues_in_Nebraska',
#  'Soccer_venues_in_Michigan',
#  'Ski_jumping_venues_in_the_United_States',
#  'American_football_venues_in_Nevada',
#  'Minnesota_Kicks_sports_facilities',
#  'New_Orleans_Pelicans_(baseball)_stadiums',
#  'National_stadiums',
#  'Egyptian-style_theaters',
#  'Towers_in_New_York_City',
#  'American_football_venues_in_Oklahoma',
#  'Theatres_completed_in_1964',
#  'Shopping_centres_in_Liverpool',
#  'Porto_Metro_stations',
#  'New_Orleans_Baby_Cakes_stadiums',
#  'Event_venues_established_in_1871',
#  'Soccer_venues_in_Saskatchewan',
#  'Transport_in_Ballarat',
#  'Urban-type_settlements_in_the_Karachay-Cherkess_Republic',
#  'American_football_venues_in_Wyoming',
#  'Sports_venues_in_Tochigi_Prefecture',
#  'American_football_venues_in_New_Hampshire',
#  'Stadiums_of_the_Commonwealth_Games',
#  'Harness_racing_venues_in_Sweden',
#  'Ski_jumping_venues_in_Slovenia',
#  'Pubs_in_Manchester',
#  'Demolished_buildings_and_structures_in_Istanbul',
#  'Sports_venues_in_Braga_District',
#  'Sports_venues_in_Friuli-Venezia_Giulia',
#  'Sports_venues_in_Essex_County,_New_Jersey',
#  'Appalachian_culture_in_Illinois',
#  'Retractable-pitch_stadiums',
#  'National_Register_of_Historic_Places_in_Volusia_County,_Florida',
#  'Libraries_in_Quebec',
#  'Jazz_clubs_in_Los_Angeles',
#  'Tennis_venues_in_Germany',
#  'Football_venues_in_Suffolk',
#  'American_football_venues_in_Alabama',
#  'Jujamcyn',
#  'LGBT_historic_places',
#  'Sports_venues_in_Orem,_Utah',
#  'Athletics_(track_and_field)_venues_in_Cape_Verde',
#  'Jazz_clubs_in_the_San_Francisco_Bay_Area',
#  'Cactus_League_venues',
#  'International_style_architecture_in_Minnesota',
#  'Sports_venues_in_Billings,_Montana',
#  'Defunct_greyhound_racing_venues_in_the_United_States',
#  'Basketball_venues_in_Columbus,_Ohio',
#  'Music_venues_in_Tokyo',
#  'Indoor_arenas_in_Columbus,_Ohio',
#  'Defunct_sports_venues_in_Washington,_D.C.',
#  'Defunct_sports_venues_in_Texas',
#  'Music_venues_in_Illinois',
#  'Defunct_sports_venues_in_Missouri',
#  'Motorsport_venues_in_Wisconsin',
#  'Defunct_motorsport_venues_in_Canada',
#  'Theatres_in_Orange_County,_California',
#  'Defunct_sports_venues_in_Alabama',
#  'McCormick_Place',
#  'New_Orleans_Brass_arenas',
#  'Sports_venues_in_Pyeongchang_County',
#  'Defunct_railway_stations_in_Barcelona',
#  '1951_disestablishments_in_Ohio',
#  'Residential_skyscrapers_in_Rochester,_New_York',
#  'Tourist_attractions_in_Pyeongchang_County',
#  'New_Orleans_Buccaneers_venues',
#  'Softball_venues_in_Connecticut',
#  'Demolished_buildings_and_structures_in_Bucharest',
#  'Sports_venues_in_Tulsa,_Oklahoma',
#  'Halls_of_fame_in_Massachusetts',
#  'Football_venues_in_Lviv',
#  'Basketball_venues_in_Salt_Lake_City',
#  'Indoor_arenas_in_Salt_Lake_City',
#  'Ski_jumping_venues_in_Canada',
#  '2014_disestablishments_in_Nebraska',
#  'Sports_venues_in_Florence_County,_South_Carolina',
#  'Sports_venues_in_Pickens_County,_South_Carolina',
#  'Football_venues_in_Donetsk_Oblast',
#  'Jazz_clubs_in_Toronto',
#  'Sports_in_York,_Pennsylvania',
#  'Infrastructure_completed_in_1893',
#  'LGBT_drinking_establishments_in_New_York_(state)',
#  'Parks_in_Oswego_County,_New_York',
#  'Defunct_basketball_venues_in_Australia',
#  'Venues_of_the_1995_Pan_American_Games',
#  'Rugby_union_stadiums_in_New_Zealand',
#  'Demolished_buildings_and_structures_in_Houston',
#  '1990_disestablishments_in_Colorado',
#  'Venues_of_the_2006_South_American_Games',
#  'Airports_in_Victoria_(Australia)',
#  'Football_venues_in_Dnipropetrovsk_Oblast',
#  'Volleyball_venues_in_Washington,_D.C.',
#  'Proposed_buildings_and_structures_in_Serbia',
#  'Sports_venues_in_South_Bend,_Indiana',
#  'Piers_in_New_York_City',
#  'Cinemas_and_movie_theaters_in_New_Jersey',
#  'High_school_football_venues_in_Texas',
#  'Sport_in_Sancaktepe',
#  'Basketball_venues_in_Chicago',
#  'Yrjö_Lindegren_buildings',
#  'FC_Barcelona_Hoquei',
#  'Sports_venues_in_Bologna',
#  'Opera_houses_in_Iran',
#  'Stadiums_under_construction_in_the_United_States',
#  'West_Virginia_University_campus',
#  'Music_venues_completed_in_1936',
#  'Sports_venues_in_Yerevan',
#  '1690s_establishments_in_Japan',
#  'Lindenwood_Lady_Lions_ice_hockey',
#  'Sports_venues_in_the_West_Midlands_(county)',
#  'Port_Kennedy,_Western_Australia',
#  'Sports_venues_in_the_Canary_Islands',
#  'Tourist_attractions_in_Sheboygan_County,_Wisconsin',
#  'Sports_venues_in_Stockton,_California',
#  'Convention_centers_in_Iceland',
#  'Basketball_venues_in_Greece',
#  '1693_establishments_in_Asia',
#  'Lamar_Cardinals_football_venues',
#  'Sports_venues_in_San_Jose,_California',
#  'Community_buildings_in_Singapore',
#  'Sports_venues_in_Barcelona',
#  'BYU_Cougars_basketball_venues',
#  'Sports_venues_in_Clearwater,_Florida',
#  'Sports_venues_in_Minneapolis–Saint_Paul',
#  'Tulsa_Roughnecks_sports_facilities',
#  'Eduardo_Souto_de_Moura_buildings',
#  'Buildings_and_structures_in_Moscow_Oblast',
#  'Netball_venues_in_South_Australia',
#  'Football_venues_in_Uzbekistan',
#  'Sports_venues_in_Uzbekistan',
#  'Notre_Dame_Fighting_Irish_football_venues',
#  'American_football_venues_in_Indiana',
#  'Speedway_venues_in_New_Zealand',
#  '1929_Barcelona_International_Exposition',
#  'Sports_venues_in_Sarpsborg',
#  'Museums_in_Uruguay',
#  'Oregon_State_Beavers_football_venues',
#  'Athletics_(track_and_field)_venues_in_Thailand',
#  'American_football_venues_in_Oregon',
#  'Tourist_attractions_in_Wood_County,_Wisconsin',
#  'Netball_venues_in_Victoria_(Australia)',
#  'Maine_Black_Bears_basketball_venues',
#  'Speedway_venues_in_Germany',
#  'Netball_venues_in_Queensland',
#  'Art_galleries_in_Massachusetts',
#  'SM_Mall_of_Asia',
#  'Tennis_venues_in_Missouri',
#  'Sports_venues_in_Belgrade',
#  'Villages_in_Essex_County,_New_York',
#  'Association_football_training_grounds_in_England',
#  'Sports_venues_in_Springfield,_Missouri',
#  'Netball_venues_in_New_South_Wales',
#  'Speedway_venues_in_Sweden',
#  'Sports_venues_in_Palermo',
#  'Villages_in_Franklin_County,_New_York',
#  'Baseball_venues_in_Utah',
#  'World_TeamTennis_stadiums',
#  'Baseball_venues_in_South_Dakota',
#  'Tourist_attractions_in_St._Croix_County,_Wisconsin',
#  'Várzea,_Praia',
#  'Stadiums_under_construction',
#  'Association_football_training_grounds_in_Brazil',
#  'Hospitals_in_Queensland',
#  'Association_football_training_grounds_in_Portugal',
#  'Sports_venues_in_Boston',
#  'Theatres_in_Almaty',
#  'Sports_venues_demolished_in_1975',
#  'Association_football_training_grounds_in_South_Korea',
#  '2013_establishments_in_Maine',
#  'Association_football_training_grounds_in_the_United_States',
#  'Olympic_polo_venues',
#  'Association_football_training_grounds_in_the_Netherlands',
#  'Association_football_training_grounds_in_Scotland',
#  'Association_football_training_grounds_in_Greece',
#  'Office_buildings_completed_in_1952',
#  'Office_buildings_completed_in_1959',
#  'Olympic_softball_venues',
#  'Nature_centers_in_New_York_City',
#  'Communist_chic',
#  'Sports_venues_demolished_in_1947',
#  '1980_disestablishments_in_Illinois',
#  'Association_football_training_grounds_in_Ukraine',
#  'Bandy_venues_in_Hungary',
#  'Association_football_training_grounds_in_Bosnia_and_Herzegovina',
#  '2012_Summer_Paralympic_venues',
#  'Association_football_training_grounds_in_Serbia',
#  'Sports_venues_demolished_in_1951',
#  'Buildings_and_structures_completed_in_1926',
#  'Sports_venues_completed_in_1950',
#  'Baseball_venues_in_the_Philippines',
#  'Tennis_venues_in_Australia',
#  'Churches_in_the_Philippines',
#  'Minnesota_United_FC_sports_facilities',
#  'Venues_of_the_2010_Winter_Olympics',
#  'Sports_venues_in_Pensacola,_Florida',
#  'Lacrosse_venues_in_Illinois',
#  'Defunct_association_football_venues',
#  'Hotels_established_in_1931',
#  'Sports_venues_in_Inverclyde',
#  'Roller_coasters_introduced_in_1895',
#  'Bradley_Braves_basketball',
#  'Convention_centers_in_Colombia',
#  'Kansas_State_University_buildings',
#  'Sport_in_the_Royal_Borough_of_Kensington_and_Chelsea',
#  'Lacrosse_venues_in_Louisiana',
#  'Tulane_Green_Wave_basketball_venues',
#  'Sports_venues_completed_in_1822',
#  'Sports_venues_in_Blackpool',
#  'Theatres_in_the_Royal_Borough_of_Kensington_and_Chelsea',
#  'Rugby_league_stadiums_in_Canada',
#  'Tennis_venues_in_the_Philippines',
#  'Tennis_venues_in_Italy',
#  'Stadiums_of_the_Asian_Games',
#  'Nightclubs_in_the_San_Francisco_Bay_Area',
#  '1975_disestablishments_in_Iowa',
#  'Tennis_venues_in_France',
#  'Swimming_venues_in_Scotland',
#  'Coulees_of_Alberta',
#  'Sports_venues_in_Kansas_City,_Missouri',
#  'Sports_venues_in_Tallahassee,_Florida',
#  'Tennis_venues_in_Japan',
#  'Sports_venues_in_Portland,_Oregon',
#  '1914_disestablishments_in_Massachusetts',
#  'Performing_groups_established_in_1965',
#  'Buildings_and_structures_in_Belém',
#  'Tourist_attractions_in_St._Clair_County,_Michigan',
#  "World's_fair_sites_in_Missouri",
#  "World's_fair_sites_in_Illinois",
#  'Thai-American_culture_in_Oregon',
#  'Sports_venues_in_Ho_Chi_Minh_City',
#  '1955_disestablishments_in_Massachusetts',
#  'Event_venues_established_in_2014',
#  'Seattle_Seahawks_stadiums',
#  'Thai-American_culture_in_New_York_(state)',
#  'Soccer_venues_in_Alabama',
#  ...]

# %%
articles_categories_file="../data/article_categories_no_unknown_types.tsv"
wcnoutput_file="../data/gini_articles_scores_0985_no_unknown_type.json"

# we get the set of article ids which have at least one section after filtering out unique sections
articles_with_sections=set(load_json("../data/article_sections_filtered.json", object_hook=article_sections_object_hook).keys())

# while in memory, we use category ids insead of their titles to save space (because the same category appears multiple times)
category_title_to_id_map=get_category_title_to_id_map()
category_id_to_title_map={v:k for k,v in category_title_to_id_map.items()}

# we ignore "container categories" ie categories which are supposed to contain only subcategories
# in the dataset from March 2021, there is one article in the category "Births" which is supposed to be a container category
container_categories=set()
with open("../data/category_graph.tsv", encoding="utf8") as f:
    for line in f:
        split_line = line.split()
        category=split_line[0]
        parent_category=split_line[1]
        if parent_category=="Container_categories":
            container_categories.add(category_title_to_id_map[category])

# we ignore categories which are not ontologically pure enough, because these will not provide sections for recommendation
pure_categories=set()
with open(wcnoutput_file, encoding="utf8") as f:
    for line in f:
        line_dict = json.loads(line)
        category = line_dict['category']
        category_id=category_title_to_id_map[category]
        pure_categories.add(category_id)
        articles=line_dict['articles']


# key: article id, value: list of categories
article_categories={}
with open(articles_categories_file, encoding="utf8") as f:
    for line in f:
        split_line = line.split()
        article_id = int(split_line[0])
        if article_id not in articles_with_sections:
            continue
        category = split_line[2]
        category_id=category_title_to_id_map[category]
        if category_id not in pure_categories:
            continue
        if category_id in container_categories:
            continue
        if article_id not in article_categories.keys():
            article_categories[article_id]=[]
        article_categories[article_id].append(category_id)

# %%
# key: category id, value: set of articles which belongs to this category
category_articles={}
for article,categories in tqdm(article_categories.items()):
    for category_id in categories:
        if category_id not in category_articles.keys():
            category_articles[category_id]=set()
        category_articles[category_id].add(article)
# Out:
#   0%|          | 0/1737697 [00:00<?, ?it/s]

# %%
def build_graph(categories,category_articles_dict,article_categories_dict):
    
    g=nx.Graph()

    # get set of all articles which belongs to at least one category in the current connected component/community
    articles_belonging_at_least_to_one_category=set().union(*[category_articles_dict[category_id] for category_id in categories])
    for article_id in articles_belonging_at_least_to_one_category:
        categories_to_connect_in_graph=[category_id for category_id in article_categories_dict[article_id] if category_id in categories]
        if len(categories_to_connect_in_graph)==1:
            g.add_node(categories_to_connect_in_graph[0])
        else:
            for i in range(len(categories_to_connect_in_graph)):
                for j in range(i+1,len(categories_to_connect_in_graph)):
                    catA=categories_to_connect_in_graph[i]
                    catB=categories_to_connect_in_graph[j]
                    if not g.get_edge_data(catA,catB):
                        g.add_edge(catA,catB,weight=1)
                    else:
                        old_weight=g.get_edge_data(catA,catB)['weight']
                        g.get_edge_data(catA,catB)['weight']=old_weight+1
    
    # normalize weights
    for edge in g.edges:
        catA=edge[0]
        catB=edge[1]
        old_weight=g.get_edge_data(catA,catB)['weight']
        n=len(category_articles_dict[catA].union(category_articles_dict[catB]))
        # probability that a randomly picked article in either catA or catB belongs to both categories
        g.get_edge_data(catA,catB)['weight']=old_weight/n
        
    return g

# %%
category_ids=[category_title_to_id_map[category] for category in  community_categories[23]]

# %%
g=build_graph(category_ids,category_articles,article_categories)

# %%
import matplotlib.pyplot as plt

def plot_graph(g,margins=0.5,font_color="red",node_color="white",relabel_categories=False,swap_pos=None,round_decimals=4,node_size=2000,spring_layout=False):
    if relabel_categories:
        g_to_plot=nx.relabel_nodes(g,category_id_to_title_map)
    else:
        g_to_plot=g.copy()
    plt.figure(figsize=(14,8))
    plt.margins(margins)
    if spring_layout:
        pos=nx.spring_layout(g_to_plot)
    else:
        pos = nx.circular_layout(g_to_plot)
    if swap_pos:
        for node_A,node_B in swap_pos.items():
            pos[node_A],pos[node_B]=pos[node_B],pos[node_A]
    nx.draw(g_to_plot,pos,with_labels=True,node_color=node_color,font_color=font_color,node_size=node_size)
    labels = nx.get_edge_attributes(g_to_plot,'weight')
    labels={(cat_A,cat_B):round(weight,round_decimals) for (cat_A,cat_B),weight in labels.items()}
    nx.draw_networkx_edge_labels(g_to_plot,pos,edge_labels=labels)

# %%
categories_to_plot=['Detroit_Red_Wings_arenas','Indoor_ice_hockey_venues_in_Detroit']

# %%
category_ids_to_plot=[category_title_to_id_map[category] for category in  categories_to_plot]

# %%
import random

# %%
category_ids_to_keep_in_graph=set()
for category_id_to_plot in category_ids_to_plot:
    category_ids_to_keep_in_graph.add(category_id_to_plot)
    for category_id in g.neighbors(category_id_to_plot):
        if random.random()<0.035:
            category_ids_to_keep_in_graph.add(category_id)

# %%
len(category_ids_to_keep_in_graph)
# Out:
# 3

# %%
for category_id_to_remove in set(g.nodes)-category_ids_to_keep_in_graph:
    g.remove_node(category_id_to_remove)

# %%
plot_graph(g,relabel_categories=True)

# %%
similar_sections_g=nx.read_edgelist("../data/example_similar_section_graphs/1",nodetype=str)

# %%
similar_sections_g1=nx.Graph()
similar_sections_g2=nx.Graph()
for i,nodes in enumerate(nx.connected_components(similar_sections_g)):
    
    for A,B in similar_sections_g.edges:
        if A in nodes and B in nodes:
            if i==0:
                similar_sections_g1.add_edge(A,B,weight=similar_sections_g.get_edge_data(A,B)['weight'])
            else:
                similar_sections_g2.add_edge(A,B,weight=similar_sections_g.get_edge_data(A,B)['weight'])

# %%
#if we take the best louvain partition, these 2 communities would be merged, if we take the first partition, they are separated
node_color_map={"Life":"pink",
                "Early_life":"pink",
                "Biography":"pink",
                "Later_career":"tab:purple",
                "Career":"tab:purple",
                "Appreciation":"tab:purple"}
plot_graph(similar_sections_g1,margins=0.5,font_color="black",node_color=[node_color_map[node] for node in similar_sections_g1.nodes])

# %%
node_color_map={"Selected_works":"red",
                "Work":"red",
                "Works":"red",
                "Compositions":"red",
                "Literature":"lime",
                "Writings":"lime",
               "Recordings":"cyan",
               "Selected_recordings":"cyan",
               "Discography":"cyan"}
plot_graph(similar_sections_g2,margins=0.05,font_color="black",node_color=[node_color_map[node] for node in similar_sections_g2.nodes],swap_pos={'Compositions':'Discography','Literature':'Selected_recordings'})

# %%
same_article_probability_g=nx.read_edgelist("../data/example_similar_section_graphs/2",nodetype=str)

# %%
nodes_to_keep=set(['Demographics','Economy','Sports','Media'])
neighbor_nodes_to_keep=set()
for section_A,section_B in same_article_probability_g.edges():
    if section_A not in nodes_to_keep or section_B not in nodes_to_keep:# or (len(set([section_A,section_B]).intersection(nodes_to_keep))==1 and random.random()<0.5):
        same_article_probability_g.remove_edge(section_A,section_B)
    else:
        neighbor_nodes_to_keep.add(section_A)
        neighbor_nodes_to_keep.add(section_B)
for node in set(same_article_probability_g.nodes)-neighbor_nodes_to_keep:
    same_article_probability_g.remove_node(node)

# %%
plot_graph(same_article_probability_g,margins=0.05,node_size=3500,spring_layout=True)

# %%
example_g=nx.Graph()
example_g.add_edge("A","B")
example_g.add_edge("A","C")
example_g.add_edge("A","D")
example_g.add_edge("C","E")
example_g.add_edge("C","F")

# %%
plot_graph(example_g,node_size=200,margins=1,swap_pos={'C':'D'})

# %%
example_g2=nx.complete_graph(4)
example_g2=nx.relabel_nodes(example_g2,{0:'A',1:'B',2:'C',3:'D'})
example_g2.add_edge("C","E")
example_g2.add_edge("C","F")
example_g2.add_edge("E","F")
plot_graph(example_g2,node_size=200,margins=1,swap_pos={'C':'D'})
